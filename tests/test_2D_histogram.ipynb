# %%
import numpy as np
import matplotlib.pyplot as plt
from pygeoinf.symmetric_space.sphere import Lebesgue

# %%
model_space = Lebesgue(4)
mu = model_space.heat_kernel_gaussian_measure(0.1)

u = mu.sample()

# %%
powers_dict = {l: np.loadtxt(f'/space/ij264/earth-tunya/geoinf_analysis/dynamic_topography/synthetic/examples/power/powers/degree_{l}.txt') for l in range(0, 21)}

# %%
Lebesgue.plot_power_spectrum_2d(powers_dict)
plt.show()
